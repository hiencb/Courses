# %%
import os
import pickle
import numpy as np
from scipy import ndimage, misc
from matplotlib import pyplot

# %%
for (dirname, dirnames, filenames) in os.walk('./Test'):
    print(dirname)
# Out:
# ./Test

# %%
data = {
    'name': 'AAC',
    'value': 3
}

dataString = pickle.dumps(data)
print(dataString)
# Out:
# b'\x80\x03}q\x00(X\x04\x00\x00\x00nameq\x01X\x03\x00\x00\x00AACq\x02X\x05\x00\x00\x00valueq\x03K\x03u.'

# %%
imageFile = './notMNIST_large/A/SW1vbnRyZWFsLU1lZGl1bS5vdGY=.png'
pixelDepth = 255.0

# imageData = ndimage.imread(imageFile)
imageData = misc.imread(imageFile)
(imageData.astype(float) - pixelDepth/2)/pixelDepth
# print(imageData.shape)
# Out:
# array([[-0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.49607843, -0.5       , -0.39019608,
#          0.14313725,  0.15490196,  0.13921569,  0.19803922, -0.18627451,
#         -0.5       , -0.48823529, -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.5       ],
#        [-0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.48823529, -0.5       ,  0.04901961,
#          0.5       ,  0.48823529,  0.48823529,  0.5       ,  0.22156863,
#         -0.5       , -0.49607843, -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.5       ],
#        [-0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
#         -0.5       , -0.5       , -0.5       , -0.5       , -0.5       ,
# ...

# %%
imageData[1, 1]
# Out:
# 0

# %%
data = np.ndarray(shape=(4, 4, 4), dtype=np.integer)
# print(data.shape)
data[0, :, :] = [[3, 4, 5, 7], [9, 4, 2, 0]]
data[1, :, :] = np.ndarray([[8, 1, 7, 3], [7, 4, 0, 2]])
data[2, :, :] = np.ndarray([[3, 9, 0, 2], [2, 8, 7, 5]])
data[3, :, :] = np.ndarray([[8, 0, 2, 5], [7, 2, 1, 8]])
pyplot.imshow(data, cmap='gray')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-e7f876c1c503> in <module>()
#       1 data = np.ndarray(shape=(4, 4, 4), dtype=np.integer)
#       2 # print(data.shape)
# ----> 3 data[0, :, :] = [[3, 4, 5, 7], [9, 4, 2, 0]]
#       4 data[1, :, :] = np.ndarray([[8, 1, 7, 3], [7, 4, 0, 2]])
#       5 data[2, :, :] = np.ndarray([[3, 9, 0, 2], [2, 8, 7, 5]])
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 4
